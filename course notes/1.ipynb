# %% [markdown]
# # 1. Tuning Parallelism
# * change the partitioning to distribute the workload more efficiently
# * minimize shuffling and avoid memory problems
#
# ### Set partitionSize
# * Set size when create RDD
# ```
# rdd = sc.parallelize(data, partitionSize)
# rdd = sc.textFile(text, partitionSize)
# ```
# * Set size when transform RDD
#     <br >shuffle
# ```
# sortBy(), sortByKey(), groupBy(), reduceByKey(), join(), leftOuterJoin(), rightOuterJoin(), partitionBy(), combineByKey(), aggregateByKey(), foldByKey(), groupByKey(), cogroup(), subtractByKey(), subtract(), repartition(), coalesce()
# ```
#
# ### Change partitionSize
# #### pair rdd
# <br>partitioned by key
#
# * HashPartitioner : partitioner using a hash value of a key.
# <br>`partitionBy(N)` uses HashPartitioner by default.
# ```
# rdd1 = rdd.partitionBy(partitionSize)
# ```
# * CustomPartitioner : User-defined paritioner.
# ```
# def custom_partitioner(key):
#     return hash(key + 10)
# pair_rdd.partitonBy(N, custom_partitioner)
# ```
# * RangePartitioner : partitioner partitioning sorted RDDs into roughly equal ranges.
# <br>`pyspark` does not have RangePartitioner
#
# #### normal rdd
# * `repartition(numPartitions: Int)`
# <br>Shuffle data across the network to create a new set of partitions.
# <br>Expensive.
# * `coalesce(numPartitions: Int, shuffle = false)`
# <br>Optimized version of repartition() – avoid data movement and reduce the number of RDD partitions.
# <br>Match the locality as much as possible, but try to balance partitions across the machines.
#
# ### Check partitionSize
# ```
# print rdd.getNumPartitions()
# print rdd.glom().collect()
# ```
#
# ### Partition-specific Methods
# * `foreachPartition()` : Apply a function to each partition of an RDD.
# * `glom()` : Return all elements within each partition.
# * `lookup(key)`: Return values for the key using the partitioner to narrow its search to only the partitions where the key would present.
# * `mapPartitions()`: Return a new RDD by applying a function to each partition of the RDD.
#
# # 2. RDD Dependencies
#
#
# # 3. Using Shared Variables
# * Accumulator : Aggregate information from executor nodes to the driver node.
#     <br> can only be used in action, not transformation
# * Broadcast variable : Efficiently distribute large read-only values to executor nodes.

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %% [markdown]
# ### EX0

# %%
text = sc.textFile('2018-msan697-example/Data/USF_Mission.txt')

# %%
text.collect()
# Out:
# [u'At USF, excellence is the standard for teaching, scholarship, creative expression, and service. Individuals from all faiths or with no religious affiliations contribute to the diversity of perspectives and experiences that are essential to our truly global education.',
#  u'',
#  u'*Care of the Whole Person',
#  u'Cura personalis \u2014 care of the whole person \u2014 is a Jesuit tradition that inspires our distinct style of education. One in which intellect is only one part of an individual\u2019s full development.',
#  u'\u201cJesuit education offers a distinctive pedagogical framework for educating the whole person (cura personalis) in which this connection between interior wisdom and exterior knowledge is made explicit."',
#  u'',
#  u'',
#  u'*Women and Men for Others',
#  u'Fr. Pedro Arrupe, S.J., in his speech to the Tenth International Congress of Jesuit Alumni of Europe, called for action. He challenged Jesuits to reflect on what they believe in and how they act. And, in doing so, inspired generations of men and women to be proactive in their service to others.',
#  u'\u201cAnyone who lives only for his or her own interests not only provides nothing for others. He or she does worse. They tend to accumulate in exclusive fashion more and more knowledge, more and more power, more and more wealth; thus denying, inevitably to those weaker than themselves their proper share of the God-given means for human development."',
#  u'USF students are inspired by this Jesuit tradition to confront the things that degrade human dignity and to expose the voices of the underserved, disadvantaged, and poor.',
#  u'',
#  u'*Core Values',
#  u'The University\u2019s core values include a belief in and a commitment to advancing:',
#  u'-the Jesuit Catholic tradition that views faith and reason as complementary resources in the search for truth and authentic human development, and that welcomes persons of all faiths or no religious beliefs as fully contributing partners to the University;',
#  u'-the freedom and the responsibility to pursue truth and follow evidence to its conclusion;',
#  u'-learning as a humanizing, social activity rather than a competitive exercise;',
#  u'-a common good that transcends the interests of particular individuals or groups; and reasoned discourse rather than coercion as the norm for decision making;',
#  u'-diversity of perspectives, experiences and traditions as essential components of a quality education in our global context;',
#  u'-excellence as the standard for teaching, scholarship, creative expression and service to the University community;',
#  u'-social responsibility in fulfilling the University\u2019s mission to create, communicate and apply knowledge to a world shared by all people and held in trust for future generations;',
#  u'-the moral dimension of every significant human choice: taking seriously how and who we choose to be in the world;',
#  u'-the full, integral development of each person and all persons, with the belief that no individual or group may rightfully prosper at the expense of others;',
#  u'-a culture of service that respects and promotes the dignity of every person.']

# %%
words = text.flatMap(lambda x:x.split(' '))

# %%
words.collect()
# Out:
# [u'At',
#  u'USF,',
#  u'excellence',
#  u'is',
#  u'the',
#  u'standard',
#  u'for',
#  u'teaching,',
#  u'scholarship,',
#  u'creative',
#  u'expression,',
#  u'and',
#  u'service.',
#  u'Individuals',
#  u'from',
#  u'all',
#  u'faiths',
#  u'or',
#  u'with',
#  u'no',
#  u'religious',
#  u'affiliations',
#  u'contribute',
#  u'to',
#  u'the',
#  u'diversity',
#  u'of',
#  u'perspectives',
#  u'and',
#  u'experiences',
#  u'that',
#  u'are',
#  u'essential',
#  u'to',
#  u'our',
#  u'truly',
#  u'global',
#  u'education.',
#  u'',
#  u'*Care',
#  u'of',
#  u'the',
#  u'Whole',
#  u'Person',
#  u'Cura',
#  u'personalis',
#  u'\u2014',
#  u'care',
#  u'of',
#  u'the',
#  u'whole',
#  u'person',
#  u'\u2014',
#  u'is',
#  u'a',
#  u'Jesuit',
#  u'tradition',
#  u'that',
#  u'inspires',
#  u'our',
#  u'distinct',
#  u'style',
#  u'of',
#  u'education.',
#  u'One',
#  u'in',
#  u'which',
#  u'intellect',
#  u'is',
#  u'only',
#  u'one',
#  u'part',
#  u'of',
#  u'an',
#  u'individual\u2019s',
#  u'full',
#  u'development.',
#  u'\u201cJesuit',
#  u'education',
#  u'offers',
#  u'a',
#  u'distinctive',
#  u'pedagogical',
#  u'framework',
#  u'for',
#  u'educating',
#  u'the',
#  u'whole',
#  u'person',
#  u'(cura',
#  u'personalis)',
#  u'in',
#  u'which',
#  u'this',
#  u'connection',
#  u'between',
#  u'interior',
#  u'wisdom',
#  u'and',
#  u'exterior',
#  u'knowledge',
#  u'is',
#  u'made',
#  u'explicit."',
#  u'',
#  u'',
#  u'*Women',
#  u'and',
#  u'Men',
#  u'for',
#  u'Others',
#  u'Fr.',
#  u'Pedro',
#  u'Arrupe,',
#  u'S.J.,',
#  u'in',
#  u'his',
#  u'speech',
#  u'to',
#  u'the',
#  u'Tenth',
#  u'International',
#  u'Congress',
#  u'of',
#  u'Jesuit',
#  u'Alumni',
#  u'of',
#  u'Europe,',
#  u'called',
#  u'for',
#  u'action.',
#  u'He',
#  u'challenged',
#  u'Jesuits',
#  u'to',
#  u'reflect',
#  u'on',
#  u'what',
#  u'they',
#  u'believe',
#  u'in',
#  u'and',
#  u'how',
#  u'they',
#  u'act.',
#  u'And,',
#  u'in',
#  u'doing',
#  u'so,',
#  u'inspired',
#  u'generations',
#  u'of',
#  u'men',
#  u'and',
#  u'women',
#  u'to',
#  u'be',
#  u'proactive',
#  u'in',
#  u'their',
#  u'service',
#  u'to',
#  u'others.',
#  u'\u201cAnyone',
#  u'who',
#  u'lives',
#  u'only',
#  u'for',
#  u'his',
#  u'or',
#  u'her',
#  u'own',
#  u'interests',
#  u'not',
#  u'only',
#  u'provides',
#  u'nothing',
#  u'for',
#  u'others.',
#  u'He',
#  u'or',
#  u'she',
#  u'does',
#  u'worse.',
#  u'They',
#  u'tend',
#  u'to',
#  u'accumulate',
#  u'in',
#  u'exclusive',
#  u'fashion',
#  u'more',
#  u'and',
#  u'more',
#  u'knowledge,',
#  u'more',
#  u'and',
#  u'more',
#  u'power,',
#  u'more',
#  u'and',
#  u'more',
#  u'wealth;',
#  u'thus',
#  u'denying,',
#  u'inevitably',
#  u'to',
#  u'those',
#  u'weaker',
#  u'than',
#  u'themselves',
#  u'their',
#  u'proper',
#  u'share',
#  u'of',
#  u'the',
#  u'God-given',
#  u'means',
#  u'for',
#  u'human',
#  u'development."',
#  u'USF',
#  u'students',
#  u'are',
#  u'inspired',
#  u'by',
#  u'this',
#  u'Jesuit',
#  u'tradition',
#  u'to',
#  u'confront',
#  u'the',
#  u'things',
#  u'that',
#  u'degrade',
#  u'human',
#  u'dignity',
#  u'and',
#  u'to',
#  u'expose',
#  u'the',
#  u'voices',
#  u'of',
#  u'the',
#  u'underserved,',
#  u'disadvantaged,',
#  u'and',
#  u'poor.',
#  u'',
#  u'*Core',
#  u'Values',
#  u'The',
#  u'University\u2019s',
#  u'core',
#  u'values',
#  u'include',
#  u'a',
#  u'belief',
#  u'in',
#  u'and',
#  u'a',
#  u'commitment',
#  u'to',
#  u'advancing:',
#  u'-the',
#  u'Jesuit',
#  u'Catholic',
#  u'tradition',
#  u'that',
#  u'views',
#  u'faith',
#  u'and',
#  u'reason',
#  u'as',
#  u'complementary',
#  u'resources',
#  u'in',
#  u'the',
#  u'search',
#  u'for',
#  u'truth',
#  u'and',
#  u'authentic',
#  u'human',
#  u'development,',
#  u'and',
#  u'that',
#  u'welcomes',
#  u'persons',
#  u'of',
#  u'all',
#  u'faiths',
#  u'or',
#  u'no',
#  u'religious',
#  u'beliefs',
#  u'as',
#  u'fully',
#  u'contributing',
#  u'partners',
#  u'to',
#  u'the',
#  u'University;',
#  u'-the',
#  u'freedom',
#  u'and',
#  u'the',
#  u'responsibility',
#  u'to',
#  u'pursue',
#  u'truth',
#  u'and',
#  u'follow',
#  u'evidence',
#  u'to',
#  u'its',
#  u'conclusion;',
#  u'-learning',
#  u'as',
#  u'a',
#  u'humanizing,',
#  u'social',
#  u'activity',
#  u'rather',
#  u'than',
#  u'a',
#  u'competitive',
#  u'exercise;',
#  u'-a',
#  u'common',
#  u'good',
#  u'that',
#  u'transcends',
#  u'the',
#  u'interests',
#  u'of',
#  u'particular',
#  u'individuals',
#  u'or',
#  u'groups;',
#  u'and',
#  u'reasoned',
#  u'discourse',
#  u'rather',
#  u'than',
#  u'coercion',
#  u'as',
#  u'the',
#  u'norm',
#  u'for',
#  u'decision',
#  u'making;',
#  u'-diversity',
#  u'of',
#  u'perspectives,',
#  u'experiences',
#  u'and',
#  u'traditions',
#  u'as',
#  u'essential',
#  u'components',
#  u'of',
#  u'a',
#  u'quality',
#  u'education',
#  u'in',
#  u'our',
#  u'global',
#  u'context;',
#  u'-excellence',
#  u'as',
#  u'the',
#  u'standard',
#  u'for',
#  u'teaching,',
#  u'scholarship,',
#  u'creative',
#  u'expression',
#  u'and',
#  u'service',
#  u'to',
#  u'the',
#  u'University',
#  u'community;',
#  u'-social',
#  u'responsibility',
#  u'in',
#  u'fulfilling',
#  u'the',
#  u'University\u2019s',
#  u'mission',
#  u'to',
#  u'create,',
#  u'communicate',
#  u'and',
#  u'apply',
#  u'knowledge',
#  u'to',
#  u'a',
#  u'world',
#  u'shared',
#  u'by',
#  u'all',
#  u'people',
#  u'and',
#  u'held',
#  u'in',
#  u'trust',
#  u'for',
#  u'future',
#  u'generations;',
#  u'-the',
#  u'moral',
#  u'dimension',
#  u'of',
#  u'every',
#  u'significant',
#  u'human',
#  u'choice:',
#  u'taking',
#  u'seriously',
#  u'how',
#  u'and',
#  u'who',
#  u'we',
#  u'choose',
#  u'to',
#  u'be',
#  u'in',
#  u'the',
#  u'world;',
#  u'-the',
#  u'full,',
#  u'integral',
#  u'development',
#  u'of',
#  u'each',
#  u'person',
#  u'and',
#  u'all',
#  u'persons,',
#  u'with',
#  u'the',
#  u'belief',
#  u'that',
#  u'no',
#  u'individual',
#  u'or',
#  u'group',
#  u'may',
#  u'rightfully',
#  u'prosper',
#  u'at',
#  u'the',
#  u'expense',
#  u'of',
#  u'others;',
#  u'-a',
#  u'culture',
#  u'of',
#  u'service',
#  u'that',
#  u'respects',
#  u'and',
#  u'promotes',
#  u'the',
#  u'dignity',
#  u'of',
#  u'every',
#  u'person.']

# %%
freq = words.map(lambda x:(x,1)).reduceByKey(lambda x,y:x+y)

# %%
freq_sort = freq.sortBy(lambda (x,y):-y)

# %%
for (x,y) in freq_sort.take(5):
    print x + ' : ' + str(y)
# Out:
# and : 25
# the : 22
# of : 19
# to : 18
# in : 13

# %%
print freq_sort.toDebugString()
# Out:
# (2) PythonRDD[63] at RDD at PythonRDD.scala:48 []
#  |  MapPartitionsRDD[61] at mapPartitions at PythonRDD.scala:427 []
#  |  ShuffledRDD[60] at partitionBy at NativeMethodAccessorImpl.java:0 []
#  +-(2) PairwiseRDD[59] at sortBy at <ipython-input-21-960059633a6f>:1 []
#     |  PythonRDD[58] at sortBy at <ipython-input-21-960059633a6f>:1 []
#     |  MapPartitionsRDD[55] at mapPartitions at PythonRDD.scala:427 []
#     |  ShuffledRDD[54] at partitionBy at NativeMethodAccessorImpl.java:0 []
#     +-(2) PairwiseRDD[53] at reduceByKey at <ipython-input-20-3bd44d96c879>:1 []
#        |  PythonRDD[52] at reduceByKey at <ipython-input-20-3bd44d96c879>:1 []
#        |  2018-msan697-example/Data/USF_Mission.txt MapPartitionsRDD[3] at textFile at NativeMethodAccessorImpl.java:0 []
#        |  2018-msan697-example/Data/USF_Mission.txt HadoopRDD[2] at textFile at NativeMethodAccessorImpl.java:0 []

# %% [markdown]
# ### EX1

# %%
import random
data = sc.parallelize(range(1,10), random.randint(1,5))

# %%
print data.getNumPartitions()
print data.glom().collect()
# Out:
# 2
# [[1, 2, 3, 4], [5, 6, 7, 8, 9]]

# %% [markdown]
# ### EX2

# %%
data = [('a',3),('b',4),('a',5)]

# %%
rdd = sc.parallelize(data, 3)

# %%
rdd_reduce1 = rdd.reduceByKey(lambda x,y:x+y)

# %%
print rdd_reduce1.getNumPartitions()
print rdd_reduce1.glom().collect()
# Out:
# 3
# [[], [('b', 4)], [('a', 8)]]

# %%
rdd_reduce2 = rdd.reduceByKey(lambda x,y:x+y, 2)

# %%
print rdd_reduce2.getNumPartitions()
print rdd_reduce2.glom().collect()
# Out:
# 2
# [[('a', 8)], [('b', 4)]]

# %%
rdd_reduce3 = rdd.reduceByKey(lambda x,y:x+y, 1)

# %%
print rdd_reduce3.getNumPartitions()
print rdd_reduce3.glom().collect()
# Out:
# 1
# [[('a', 8), ('b', 4)]]

# %% [markdown]
# ### EX3

# %% [markdown]
# #### Set partitionSize
# * Set size when create RDD
# ```
# rdd = sc.parallelize(data, partitionSize)
# rdd = sc.textFile(text, partitionSize)
# ```
# * Set size when transform RDD
#     <br >shuffle
# ```
# sortBy(), sortByKey(), groupBy(), reduceByKey(), join(), leftOuterJoin(), rightOuterJoin(), partitionBy(), combineByKey(), aggregateByKey(), foldByKey(), groupByKey(), cogroup(), subtractByKey(), subtract(), repartition(), coalesce()
# ```
#
# #### Change partitionSize
# * HashPartitioner : partitioner using a hash value of a key.
# <br>`partitionBy(N)` uses HashPartitioner by default.
# ```
# rdd1 = rdd.partitionBy(partitionSize)
# ```
# * CustomPartitioner : User-defined paritioner.
# ```
# def custom_partitioner(key):
#     return hash(key + 10)
# pair_rdd.partitonBy(N, custom_partitioner)
# ```
# * RangePartitioner : partitioner partitioning sorted RDDs into roughly equal ranges.
# <br>`pyspark` does not have RangePartitioner
#
# #### Check partitionSize
# ```
# print rdd.getNumPartitions()
# print rdd.glom().collect()
# ```

# %%
rdd_change = rdd.partitionBy(2)

# %%
print rdd_change.getNumPartitions()
print rdd_change.glom().collect()
# Out:
# 2
# [[('a', 3), ('a', 5)], [('b', 4)]]

# %% [markdown]
# ### EX4

# %%
lines1 = sc.textFile("2018-msan697-example/Data/filtered_registered_business_sf.csv") 
lines2 = sc.textFile("2018-msan697-example/Data/supervisor_sf.csv")

# %% [markdown]
# * without partition

# %%
sf_business1 = lines1.map(lambda x: (x.split(",")[0],x)).persist()
supervisor1 = lines2.map(lambda x: (x.split(",")[0],x)).persist()

# %%
print sf_business1.getNumPartitions()
print supervisor1.getNumPartitions()
# Out:
# 2
# 2

# %%
import time
start = time.time()
sf_business1.join(supervisor1).collect()
print time.time() - start
# Out:
# 1.18877005577

# %%
sf_business1.join(supervisor1).glom().collect()
# Out:
# [[(u'94123',
#    (u'94123,Tournahu George L,3301 Broderick St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Amore Robert,1958 Union St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Aunt Anns Corp Headquarters,2722 Gough St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Barbagelata & Co Inc,2381 Chestnut St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Boas International Motors Inc,2098 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Books Inc,2251 Chestnut St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Boswell Alliance Const Co Inc,1686 Union St 306,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Lew Willie L & Po S,2102 Filbert St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Gabriels Horn Inc,1901 Union St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Joseph Caston Md,2710 Broderick St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Del Camp Investments Inc,2755 Webster St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Del Camp Investments Inc,2755 Webster St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Del Camp Investments Inc,2100 Chestnut St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Del Camp Investments Inc,3755 Fillmore St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Del Camp Investments Inc,3755 Fillmore St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Del Camp Investments Inc,3124 Octavia,San+francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Del Camp Investments Inc,3124 Octavia St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Dewolf Realty Co,28-34 Richardson Ave,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Dewolf Realty Co,1961 Filbert St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Dewolf Realty Co,1 Toledo Way,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Dewolf Realty Co,2290 North Point St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Dewolf Realty Co,3060 Scott St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Dewolf Realty Co,3660 Scott St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Dewolf Realty Co,2270 North Point St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Dudum Manuel G,36 Cervantes Blvd,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,E I Du Pont De Nemours & Co,2755 Franklin St 6,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Frank Roy M,3314 Steiner St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Quade Dennis G,1776 Green St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Herrgott & Wilson Inc,3328 Steiner St 1,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,"Hoogasian Flowers, Inc.",1674 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Tom Allen & Denise,1807 Union St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Bocci Jc Barry Mcnamara Etal,2001 Union St 480,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Fong Jack Lee & Dorothy D,2439 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,The Bernard Corporation,2036 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Linoleum Larrys Inc,2598 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Boscos Delicatessen Inc,2120 Chestnut St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Martin John-Marie-Langlois D,3007 Fillmore St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Merrill Lynch Pierce Etal Inc,2200 Chestnut St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Merrill Lynch Pierce Etal Inc,1995 Union St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Dr Monetta Od A Prof Corp,2189 Union St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Kai Motels Inc,1895 Lombard St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Ed Demartini,3251 Scott St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Yee Shubert Y,1545 Lombard St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Yee Shubert Y,3326 Laguna St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Rs Corporation,1799 Lombard St Str#3806,San+francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Realty Equities Inc,2353 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Realty Equities Inc,2436 Greenwich St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Realty Equities Inc,2464 Greenwich St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Realty Equities Inc,2395 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Realty Equities Inc,2353 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Realty Equities Inc,2436 Greenwich St 5,San Francisco,CA',
#     u'94123,2')),
#   (u'94123', (u'94123,Moret Remy,2900 Lyon St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Romano Gloria,2030 Lombard St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Safeway Inc,15 Marina Blvd,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Schurman Fine Papers,1888 Union St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Shiota Paul K,3131 Fillmore St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Chevron Texaco Corp,1598 Bay St 985,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Chevron Texaco Corp,1790 Lombard St 3535,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Chevron Texaco Corp,2301 Lombard St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Sloat Garden Center Inc,3237 Pierce St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Thele William R Jr,2265 Union St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Tock Corporation,2023 Beach St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Shazam Enterprises,2401 Chestnut St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Uptons Inc,2435 Lombard St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,A. Valente & Sons Inc,1877 Union St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Van Galen Leo,2150 Union St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Walgreen Co,3201 Divisadero St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Walgreen Co,2141 Chestnut St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Disney Anne M,1 Mallorca Way,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Disney Anne M,2050 Chestnut St,San Francisco,CA', u'94123,2')),
#   (u'94123', (u'94123,William Eva,100 Capra Wy,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Langbein K & Vizzard M,101 Cervantes Blvd,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Papazian Emmy,2847 Fillmore St,San Francisco,CA', u'94123,2')),
#   (u'94123', (u'94123,Wong Poy,1851 Vallejo St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Gucker Bernard  & Lina,2485 Chestnut St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Fireside Egon,2276 Greenwich St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Chiao Johnson L & Diane W,1215 Bay St,San Francisco,CA',
#     u'94123,2')),
#   (u'94123',
#    (u'94123,Tappe Julius M,1530 Green St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Andrew W Lee Etal,1490 Chestnut St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,Chan Silk H,1234 Francisco St,San Francisco,CA', u'94123,2')),
#   (u'94123',
#    (u'94123,
,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Drobey Rejane,2504 Bush St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Drobey Rejane,1825 Scott St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Drobey Rejane,1825 Scott St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Drobey Rejane,1825 Scott St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1508 Mcallister St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1508 Mcallister St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1508 Mcallister St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1508 Mcallister St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1508 Mcallister St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1508 Mcallister St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1869-73 Golden Gate Ave.,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1869-73 Golden Gate Ave.,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Dahan Jacques,1869-73 Golden Gate Ave.,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,Hassid Edwin J Md,2300 Sutter St 203,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Hassid Edwin J Md,2300 Sutter St 203,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Hassid Edwin J Md,2300 Sutter St 203,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,Brown Robert C,2119 Bush St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Brown Robert C,2119 Bush St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Brown Robert C,2119 Bush St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Rhode John Grant & Ann A,1911 Divisadero St,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Rhode John Grant & Ann A,1911 Divisadero St,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Rhode John Grant & Ann A,1911 Divisadero St,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,Lee Kim & Vivian,1971 Fillmore St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Lee Kim & Vivian,1971 Fillmore St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Lee Kim & Vivian,1971 Fillmore St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Ten Asa Usa Inc,1737 Post St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Ten Asa Usa Inc,1737 Post St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Ten Asa Usa Inc,1737 Post St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 207,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 207,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 207,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 209,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 209,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 209,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 203,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 203,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1730 Geary Blvd 203,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1737 Post St 365,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1737 Post St 365,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Sakakihara Asakichi,1737 Post St 365,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,King Sue F,3067 Sacramento St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,King Sue F,3067 Sacramento St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,King Sue F,3067 Sacramento St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Morris Diane L,2550 Scott St,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Morris Diane L,2550 Scott St,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Morris Diane L,2550 Scott St,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,2')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,1')),
#   (u'94115',
#    (u'94115,Gilmore Preston E,1770 Post St 156,San Francisco,CA', u'94115,5')),
#   (u'94115',
#    (u'94115,Norris Barbara & Schmidt Max,2285 Broadway St,San Francisco,CA',
#     u'94115,2')),
#   (u'94115',
#    (u'94115,Norris Barbara & Schmidt Max,2285 Broadway St,San Francisco,CA',
#     u'94115,1')),
#   (u'94115',
#    (u'94115,Norris Barbara & Schmidt Max,2285 Broadway St,San Francisco,CA',
#     u'94115,5')),
#   (u'94115',
#    (u'94115,Gothelf Michael J,2984 Clay St,San Francisco,CA', u'94115,2')),
#   ...]]

# %% [markdown]
# * with partition

# %%
partitionSize = 4

# %%
sf_business2 = lines1.map(lambda x: (x.split(",")[0],x)).partitionBy(partitionSize).persist()
supervisor2 = lines2.map(lambda x: (x.split(",")[0],x)).partitionBy(partitionSize).persist()

# %%
print sf_business2.getNumPartitions()
print supervisor2.getNumPartitions()
# Out:
# 4
# 4

# %%
import time
start = time.time()
sf_business2.join(supervisor2).collect()
print time.time() - start
# Out:
# 1.44442105293

# %% [markdown]
# ### EX5

# %%
nums = sc.parallelize([(1,2),(3,4),(5,1),(2,3),(1,5)])

# %%
nums.partitionBy(4).glom().collect()
# Out:
# [[], [(1, 2), (5, 1), (1, 5)], [(2, 3)], [(3, 4)]]

# %%
def hash_partition(key):
    return hash(key)
def custom_partition(key):
    return hash(key + 10)

# %%
nums.partitionBy(4, hash_partition).glom().collect()
# Out:
# [[], [(1, 2), (5, 1), (1, 5)], [(2, 3)], [(3, 4)]]

# %%
nums.partitionBy(4, custom_partition).glom().collect()
# Out:
# [[(2, 3)], [(3, 4)], [], [(1, 2), (5, 1), (1, 5)]]

# %% [markdown]
# ### Repartition
# * `repartition(numPartitions: Int)`
# <br>Shuffle data across the network to create a new set of partitions.
# <br>Expensive.
# * `coalesce(numPartitions: Int, shuffle = false)`
# <br>Optimized version of repartition() – avoid data movement and reduce the number of RDD partitions.
# <br>Match the locality as much as possible, but try to balance partitions across the machines.

# %% [markdown]
# ### EX6

# %%
nums = sc.parallelize([1,1,3,3,11,13,14], 5)
partitionSize = 8
nums_re = nums.repartition(partitionSize)
nums_co = nums.coalesce(partitionSize)
print nums_re.toDebugString()
print nums_co.toDebugString()
# Out:
# (8) MapPartitionsRDD[908] at coalesce at <unknown>:0 []
#  |  CoalescedRDD[907] at coalesce at <unknown>:0 []
#  |  ShuffledRDD[906] at coalesce at <unknown>:0 []
#  +-(5) MapPartitionsRDD[905] at coalesce at <unknown>:0 []
#     |  PythonRDD[904] at RDD at PythonRDD.scala:48 []
#     |  ParallelCollectionRDD[903] at parallelize at PythonRDD.scala:480 []
# (5) CoalescedRDD[909] at coalesce at <unknown>:0 []
#  |  ParallelCollectionRDD[903] at parallelize at PythonRDD.scala:480 []

# %%
nums = sc.parallelize([1,1,3,3,11,13,14], 5)
partitionSize = 3
print nums.glom().collect()
print nums.repartition(partitionSize).glom().collect()
print nums.coalesce(partitionSize).glom().collect()
print nums.coalesce(partitionSize, shuffle = True).glom().collect()
# Out:
# [[1], [1], [3, 3], [11], [13, 14]]
# [[11, 13, 14], [1, 1], [3, 3]]
# [[1], [1, 3, 3], [11, 13, 14]]
# [[11, 13, 14], [1, 1], [3, 3]]

# %%
nums = sc.parallelize([1,1,3,3,11,13,14], 5)
partitionSize = 10
print nums.glom().collect()
print nums.repartition(partitionSize).glom().collect()
# By default, `coalesce` can only reduce the number of RDD partition
print nums.coalesce(partitionSize).glom().collect()
print nums.coalesce(partitionSize, shuffle = True).glom().collect()
# Out:
# [[1], [1], [3, 3], [11], [13, 14]]
# [[], [1], [], [13, 14], [], [11], [1], [], [], [3, 3]]
# [[1], [1], [3, 3], [11], [13, 14]]
# [[], [1], [], [13, 14], [], [11], [1], [], [], [3, 3]]

# %% [markdown]
# ### EX8

# %%
list = [random.randrange(10) for x in range(500)]

# %%
listrdd = sc.parallelize(list, 5)

# %%
pairs = listrdd.map(lambda x:(x,x*x))

# %%
print pairs.toDebugString()
# Out:
# (5) PythonRDD[828] at RDD at PythonRDD.scala:48 []
#  |  ParallelCollectionRDD[819] at parallelize at PythonRDD.scala:480 []

# %%
reduced = pairs.reduceByKey(lambda x,y:x+y, 3)

# %%
reduced.glom().collect()
# Out:
# [[(0, 0), (9, 3888), (3, 495), (6, 1692)],
#  [(1, 44), (4, 832), (7, 3038)],
#  [(8, 2880), (2, 172), (5, 1300)]]

# %%
print reduced.toDebugString()
# Out:
# (3) PythonRDD[834] at RDD at PythonRDD.scala:48 []
#  |  MapPartitionsRDD[832] at mapPartitions at PythonRDD.scala:427 []
#  |  ShuffledRDD[831] at partitionBy at <unknown>:0 []
#  +-(5) PairwiseRDD[830] at reduceByKey at <ipython-input-252-fef1e9323331>:1 []
#     |  PythonRDD[829] at reduceByKey at <ipython-input-252-fef1e9323331>:1 []
#     |  ParallelCollectionRDD[819] at parallelize at PythonRDD.scala:480 []

# %%
finalrdd = reduced.mapPartitions(lambda itr:['K='+str(k)+',V='+str(v) for (k,v) in itr])

# %%
finalrdd.glom().collect()
# Out:
# [['K=0,V=0', 'K=9,V=3888', 'K=3,V=495', 'K=6,V=1692'],
#  ['K=1,V=44', 'K=4,V=832', 'K=7,V=3038'],
#  ['K=8,V=2880', 'K=2,V=172', 'K=5,V=1300']]

# %%
print finalrdd.toDebugString()
# Out:
# (3) PythonRDD[836] at RDD at PythonRDD.scala:48 []
#  |  MapPartitionsRDD[832] at mapPartitions at PythonRDD.scala:427 []
#  |  ShuffledRDD[831] at partitionBy at <unknown>:0 []
#  +-(5) PairwiseRDD[830] at reduceByKey at <ipython-input-252-fef1e9323331>:1 []
#     |  PythonRDD[829] at reduceByKey at <ipython-input-252-fef1e9323331>:1 []
#     |  ParallelCollectionRDD[819] at parallelize at PythonRDD.scala:480 []

# %% [markdown]
# ### EX9

# %%
accum1 = sc.accumulator(0)
accum2 = sc.accumulator(0)

# %%
nums = sc.parallelize(range(1, 10000001))
nums.take(4)
# Out:
# [1, 2, 3, 4]

# %%
import time
start = time.time()
nums.foreach(lambda x:accum1.add(1))
print time.time()-start
# Out:
# 1.334649086

# %%
import time
start = time.time()
for x in range(1, 10000001):
    accum2.add(1)
print time.time()-start
# Out:
# 4.02622294426

# %%
print accum1.value
print accum2.value
# Out:
# 10000000
# 10000000

# %% [markdown]
# ### EX10

# %%
text = sc.textFile('2018-msan697-example/Data/bike_share/status.csv').map(lambda x:x.split(',')[0])

# %%
text.count()
# Out:
# 36647622

# %%
text.take(10)
# Out:
# [u'10', u'10', u'10', u'10', u'10', u'10', u'10', u'10', u'10', u'10']

# %%
accum1 = sc.accumulator(0)
accum2 = sc.accumulator(0)
def myaccum(x):
    if x == '10':
        accum1.add(1)
        return x

text_filter = text.map(myaccum)
text_filter.foreach(lambda x:accum2.add(1))
print text_filter.count()
print accum1.value
print accum2.value
# Out:
# 36647622
# 1047246
# 36647622

# %%
text.filter(lambda x:x== '10').count()
# Out:
# 523623

# %% [markdown]
# ### EX11

# %%
list = sc.parallelize(range(10,100))

# %%
broadcastValue = sc.broadcast([1,2,3])

# %%
type(broadcastValue)
# Out:
# pyspark.broadcast.Broadcast

# %%
broadcastValue.value
# Out:
# [1, 2, 3]

# %%
broadcastValue.value[0]
# Out:
# 1

# %%
add_broadcastValue = list.map(lambda x:x+broadcastValue.value[0])

# %%
add_broadcastValue.take(2)
# Out:
# [11, 12]

# %%
broadcastValue.unpersist()
broadcastValue.value
# Out:
# [1, 2, 3]

# %% [markdown]
# ### EX12

# %%
text = sc.textFile('2018-msan697-example/Data/bike_share/status.csv').map(lambda x:x.split(','))

# %%
text.take(2)
# Out:
# [[u'10', u'7', u'8', u'"2014-12-30 15:37:02"'],
#  [u'10', u'7', u'8', u'"2014-12-30 15:35:02"']]
